# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/boot/nuclear.csv')
df
# Out:
#     rownames    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0          1  460.05  68.58  14  46   687   0   1   0   0     14   0
# 1          2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 2          3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 3          4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 4          5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 5          6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 6          7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 7          8  317.21  68.42  14  59   457   0   0   0   0      1   0
# 8          9  457.12  68.42  15  55   822   1   0   0   0      5   0
# 9         10  690.19  68.33  12  71   792   0   1   1   1      2   0
# 10        11  350.63  68.58  12  64   560   0   0   0   0      3   0
# 11        12  402.59  68.75  13  47   790   0   1   0   0      6   0
# 12        13  412.18  68.42  15  62   530   0   0   1   0      2   0
# ...

# %%
print(sum(int(el) for el in df.cost) / len(df.cost))
# Out:
# 461.09375

# %%
sum(df['ne'].values)
# Out:
# 8

# %%
df_sorted_by_date = df.sort_values(by=['date'])
df_sorted_by_date
df_sorted_by_date.reset_index(drop=True, inplace=True)
df_sorted_by_date
# Out:
#     rownames    cost   date  t1  t2   cap  pr  ne  ct  bw  cum.n  pt
# 0         28  288.48  67.17   9  48   821   0   0   1   0      7   1
# 1         27  207.51  67.25  13  63   745   0   0   0   0      8   1
# 2         31  217.38  67.25  13  72   745   1   0   0   0      8   1
# 3          2  452.99  67.33  10  73  1065   0   0   1   0      1   0
# 4          3  443.22  67.33  10  85  1065   1   0   1   0      1   0
# 5         32  270.71  67.83   7  80   886   1   0   0   1     11   1
# 6         30  280.36  67.83  12  71   886   1   0   0   1     11   1
# 7         29  284.88  67.83  12  63   886   0   0   0   1     11   1
# 8          6  345.39  67.92  13  51   514   0   1   1   0      3   0
# 9          4  652.32  68.00  11  67  1065   0   1   1   0     12   0
# 10         5  642.23  68.00  11  78  1065   1   1   1   0     12   0
# 11         7  272.37  68.17  12  50   822   0   0   0   0      5   0
# 12        10  690.19  68.33  12  71   792   0   1   1   1      2   0
# ...

# %%
plt.plot(df_sorted_by_date.date, df_sorted_by_date.cost)
plt.xlabel('date')
plt.ylabel('cost')
plt.show()

# %%
pr_df = df.loc[df.pr == 1]
max(pr_df['cap'])
# Out:
# 1065
